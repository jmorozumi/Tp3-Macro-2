# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve

# %%
# Asumir valores para las constantes
a = 0.58
b = 0.1
r = 0.04
A = 1.5
alpha = 1.72

# Crear un rango de valores para w
w_values = np.linspace(0, 1, 100)

# Calcular las funciones
Ve_minus_Vu = w_values / (a + b + r)
Vf_minus_Vv = (A - w_values) / (alpha + b + r)

# Graficar las funciones
plt.figure(figsize=(10, 6))
plt.plot(w_values, Ve_minus_Vu, label=r'$Ve - Vu = \frac{w}{a + b + r}$')
plt.plot(w_values, Vf_minus_Vv, label=r'$Vf - Vv = \frac{A - w}{alpha + b + r}$')
plt.xlabel('SALARIOS')
plt.ylabel('Beneficios')
plt.title('Salario de Equilibrio Modelo DMP')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Suponemos el shock de la subida de A de 1,5 
#Parámetros y funciones supuestas
def alpha(E):
    return (100 - E) / (0.1 * E) 

def a(E):
    return 0.1 * E /(100 - E)  

b = 0.1
r = 0.04
C = 1
E = 85

# Valores de A
A = 1.5

# Valores de empleo
E = np.linspace(0, 100, 500)

# Función rV_V(E)
def rVV(E, A):
    return -C + (alpha(E) / (a(E) + alpha(E) + 2*b + 2*r)) * A

# Cálculo de rV_V(E) para A.
rVV = rVV(E, A)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(E, rVV, label='A', color='blue')
plt.axhline(0, color='gray', linewidth=0.5)
plt.title('Equilibrio Modelo DMP')
plt.xlabel('Empleo')
plt.ylabel('rV_V')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/pv/088xlq6n437b0m1bfcy9zv840000gn/T/ipykernel_49956/2516045729.py:4: RuntimeWarning: divide by zero encountered in divide
#   return (100 - E) / (0.1 * E)
# /var/folders/pv/088xlq6n437b0m1bfcy9zv840000gn/T/ipykernel_49956/2516045729.py:7: RuntimeWarning: divide by zero encountered in divide
#   return 0.1 * E /(100 - E)
# /var/folders/pv/088xlq6n437b0m1bfcy9zv840000gn/T/ipykernel_49956/2516045729.py:22: RuntimeWarning: invalid value encountered in divide
#   return -C + (alpha(E) / (a(E) + alpha(E) + 2*b + 2*r)) * A
